# %% [markdown]
# # Advanced affine diagnostics and non-rigid correction: WS2 0070/0071
#
# This pair demonstrates a failure mode specific to periodic atomic images. A
# whole-image affine score can prefer a neighboring unit-cell translation even
# when defects no longer correspond. The upper-left region contains trustworthy
# defect correspondence, so it establishes the affine branch for the complete
# field. Regional diagnostics then show where non-rigid correction is still
# needed.
#
# This is an **advanced validation workflow**. Start with the normal automatic
# `correct_affine()` tutorial for routine data. Use this notebook only when the
# RGB overlay shows a unit-cell hop or different regions prefer different rigid
# translations.
#
# The regional affine anchor selects the correct lattice branch. This difficult
# pair then uses six knots per scanline so non-rigid correction can represent
# the fast-scan variation that remains across the complete field.
#
# Download the [raw WS2 0070/0071 data](https://drive.google.com/drive/folders/1boOS-dTl9gnW9CbfA7BKLy5fDJ5cXpkx?usp=sharing) and place the files in `tutorials/data/robustness/wmill_ws2/`.

# %% [markdown]
# ## Device and paths

# %%
from pathlib import Path

import quantem.widget as qw
from quantem.imaging import DriftCorrection

DATA = Path("../data/robustness/wmill_ws2")
RESULT = DATA / "drift_0070_0071_diagnostics.zip"

# Interactive is the recommended default. False uses static/report rendering.
INTERACTIVE = True
VIEW_MODE = "interactive" if INTERACTIVE else "static"

qw.profile()
# Out:
# quantem.widget  0.0.1rc37
#   install       published package
# quantem.gpu     0.0.1rc6
#   install       source override (differs from installed metadata)
# quantem         0.1.9
# torch           2.13.0  device=cuda (NVIDIA RTX PRO 6000)
# GPUs            1 visible (CUDA_VISIBLE_DEVICES=0)
#   GPU0           25.2 used / 102 GB  (77 free)
#   torch pool    0.0 live / 0.0 reserved GB
# python          3.14.6

# %% [markdown]
# ## Load the orthogonal EMD pair
#
# `from_emd` reads both scan directions and calibration from Velox metadata.

# %%
drift = DriftCorrection.from_emd(
    DATA / "0070 - VWS2_9h_g_300kv STEM HAADF 5.20 Mx Diffraction.emd",
    DATA / "0071 - VWS2_9h_g_300kv STEM HAADF 5.20 Mx Diffraction.emd",
    verbose=False,
)

# %% [markdown]
# ## Fit affine from the trusted upper-left region
#
# `region="top_left"` selects the physical upper-left quadrant without requiring
# Python slice syntax. `correct_affine()` fits one affine drift vector and one
# translation there, then applies that same affine model to the complete scans.
# Knot count remains a non-rigid decision made later in the workflow. Both
# orthogonal scans remain free.

# %%
drift.correct_affine(
    region="top_left",
    region_smoothing_sigma=4.0,
    max_image_shift=64,
    show_combined=False,
    show_scans=False,
    show_knots=False,
    verbose=True,
)
# Out:
# correct_affine: automatic pyramid 8x, 5 native candidates, 0.49 s
# Drift: (-0.01367, +0.03555) px/line; translation bound 64 px

# %% [markdown]
# ## Inspect the affine result

# %%
drift.plot_combined(
    stage=("initial", "affine"),
    interactive=INTERACTIVE,
    width=620,
)

# %% [markdown]
# ## Regional affine diagnostic
#
# The search uses sigma 4 for stability, but acceptance is checked with sigma
# 0.5 so atomic detail remains visible. The title records the trusted region and
# the single affine drift vector applied to the complete image. Each row is one
# physical quadrant. The four columns show scan 0, scan 1, their actual RGB
# registration, and the absolute residual difference. The table's
# NCC, yellow agreement, and mean absolute difference describe the result as it
# stands. This diagnostic neither searches for nor applies another shift.

# %%
affine_figure, affine_regions = drift.diagnose_affine(
    stage="affine",
    smoothing_sigma=0.5,
)

# %%
affine_regions
# Out:
#          region         region_role  row_start  row_stop  column_start  \
# 0      top left  trusted affine fit          0      1024             0
# 1     top right   validation region          0      1024          1024
# 2   bottom left   validation region       1024      2048             0
# 3  bottom right   validation region       1024      2048          1024
#
#    column_stop  grid_row  grid_column  current_ncc  current_yellow  \
# 0         1024         0            0     0.470790        0.543680
# 1         2048         0            1     0.329995        0.473621
# 2         1024         1            0     0.269714        0.454064
# 3         2048         1            1    -0.098319        0.371826
#
#    mean_absolute_difference
# 0                  0.041223
# 1                  0.039716
# 2                  0.044296
# 3                  0.053800

# %% [markdown]
# ## Apply the selected non-rigid model
#
# Both scans remain free, so each contributes its scan-direction-dependent
# drift. Six knots per scanline resolve the left/right residual difference while
# keeping the deformation model compact. Smoothing 2 suppresses scanline jitter
# while retaining that fast-scan freedom. Early stopping after 16 unchanged
# cycles prevents continued deformation once the registration has flattened.

# %%
drift.correct_nonrigid(
    num_knots=6,
    optimizer="adam",
    num_refine_cycles=256,
    optimizer_steps=30,
    learning_rate=0.1,
    knot_smoothing_sigma=2.0,
    update_fraction=0.8,
    trend_order=1,
    max_image_shift=32,
    loss="mse",
    early_stop_patience=16,
    min_iterations=4,
    show_combined=False,
    show_scans=False,
    show_knots=False,
    verbose=True,
)
# Out:
# Solving nonrigid drift (adam):   0%|          | 0/256 [00:00<?, ?it/s]
# Solving nonrigid drift (adam):   0%|          | 0/256 [00:03<?, ?it/s, error=0.005733, best=0.005733]
# Solving nonrigid drift (adam):   0%|          | 1/256 [00:03<13:40,  3.22s/it, error=0.005733, best=0.005733]
# Solving nonrigid drift (adam):   0%|          | 1/256 [00:03<13:40,  3.22s/it, error=0.005078, best=0.005078]
# Solving nonrigid drift (adam):   0%|          | 1/256 [00:03<13:40,  3.22s/it, error=0.004675, best=0.004675]
# Solving nonrigid drift (adam):   1%|          | 3/256 [00:03<03:47,  1.11it/s, error=0.004675, best=0.004675]
# Solving nonrigid drift (adam):   1%|          | 3/256 [00:03<03:47,  1.11it/s, error=0.004442, best=0.004442]
# Solving nonrigid drift (adam):   1%|          | 3/256 [00:03<03:47,  1.11it/s, error=0.004078, best=0.004078]
# Solving nonrigid drift (adam):   2%|▏         | 5/256 [00:03<02:02,  2.06it/s, error=0.004078, best=0.004078]
# Solving nonrigid drift (adam):   2%|▏         | 5/256 [00:03<02:02,  2.06it/s, error=0.003923, best=0.003923]
# Solving nonrigid drift (adam):   2%|▏         | 6/256 [00:03<01:35,  2.61it/s, error=0.003923, best=0.003923]
# Solving nonrigid drift (adam):   2%|▏         | 6/256 [00:03<01:35,  2.61it/s, error=0.003832, best=0.003832]
# Solving nonrigid drift (adam):   3%|▎         | 7/256 [00:03<01:15,  3.28it/s, error=0.003832, best=0.003832]
# Solving nonrigid drift (adam):   3%|▎         | 7/256 [00:03<01:15,  3.28it/s, error=0.003777, best=0.003777]
# Solving nonrigid drift (adam):   3%|▎         | 8/256 [00:03<01:01,  4.04it/s, error=0.003777, best=0.003777]
# Solving nonrigid drift (adam):   3%|▎         | 8/256 [00:03<01:01,  4.04it/s, error=0.003744, best=0.003744]
# Solving nonrigid drift (adam):   4%|▎         | 9/256 [00:03<00:50,  4.88it/s, error=0.003744, best=0.003744]
# Solving nonrigid drift (adam):   4%|▎         | 9/256 [00:04<00:50,  4.88it/s, error=0.003725, best=0.003725]
# Solving nonrigid drift (adam):   4%|▍         | 10/256 [00:04<00:43,  5.72it/s, error=0.003725, best=0.003725]
# Solving nonrigid drift (adam):   4%|▍         | 10/256 [00:04<00:43,  5.72it/s, error=0.003713, best=0.003713]
# Solving nonrigid drift (adam):   4%|▍         | 11/256 [00:04<00:37,  6.53it/s, error=0.003713, best=0.003713]
# Solving nonrigid drift (adam):   4%|▍         | 11/256 [00:04<00:37,  6.53it/s, error=0.003705, best=0.003705]
# Solving nonrigid drift (adam):   5%|▍         | 12/256 [00:04<00:33,  7.26it/s, error=0.003705, best=0.003705]
# Solving nonrigid drift (adam):   5%|▍         | 12/256 [00:04<00:33,  7.26it/s, error=0.0037, best=0.0037]
# Solving nonrigid drift (adam):   5%|▌         | 13/256 [00:04<00:30,  7.87it/s, error=0.0037, best=0.0037]
# Solving nonrigid drift (adam):   5%|▌         | 13/256 [00:04<00:30,  7.87it/s, error=0.003697, best=0.003697]
# Solving nonrigid drift (adam):   5%|▌         | 14/256 [00:04<00:28,  8.35it/s, error=0.003697, best=0.003697]
# Solving nonrigid drift (adam):   5%|▌         | 14/256 [00:04<00:28,  8.35it/s, error=0.003694, best=0.003694]
# Solving nonrigid drift (adam):   6%|▌         | 15/256 [00:04<00:27,  8.76it/s, error=0.003694, best=0.003694]
# Solving nonrigid drift (adam):   6%|▌         | 15/256 [00:04<00:27,  8.76it/s, error=0.003692, best=0.003692]
# Solving nonrigid drift (adam):   6%|▋         | 16/256 [00:04<00:26,  9.07it/s, error=0.003692, best=0.003692]
# Solving nonrigid drift (adam):   6%|▋         | 16/256 [00:04<00:26,  9.07it/s, error=0.003691, best=0.003691]
# Solving nonrigid drift (adam):   7%|▋         | 17/256 [00:04<00:25,  9.30it/s, error=0.003691, best=0.003691]
# Solving nonrigid drift (adam):   7%|▋         | 17/256 [00:04<00:25,  9.30it/s, error=0.00369, best=0.00369]
# Solving nonrigid drift (adam):   7%|▋         | 18/256 [00:04<00:25,  9.46it/s, error=0.00369, best=0.00369]
# Solving nonrigid drift (adam):   7%|▋         | 18/256 [00:05<00:25,  9.46it/s, error=0.003689, best=0.003689]
# Solving nonrigid drift (adam):   7%|▋         | 19/256 [00:05<00:24,  9.59it/s, error=0.003689, best=0.003689]
# Solving nonrigid drift (adam):   7%|▋         | 19/256 [00:05<00:24,  9.59it/s, error=0.003688, best=0.003688]
# Solving nonrigid drift (adam):   8%|▊         | 20/256 [00:05<00:24,  9.66it/s, error=0.003688, best=0.003688]
# Solving nonrigid drift (adam):   8%|▊         | 20/256 [00:05<00:24,  9.66it/s, error=0.003688, best=0.003688]
# Solving nonrigid drift (adam):   8%|▊         | 21/256 [00:05<00:24,  9.73it/s, error=0.003688, best=0.003688]
# Solving nonrigid drift (adam):   8%|▊         | 21/256 [00:05<00:24,  9.73it/s, error=0.003687, best=0.003687]
# Solving nonrigid drift (adam):   9%|▊         | 22/256 [00:05<00:23,  9.77it/s, error=0.003687, best=0.003687]
# Solving nonrigid drift (adam):   9%|▊         | 22/256 [00:05<00:23,  9.77it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):   9%|▉         | 23/256 [00:05<00:23,  9.80it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):   9%|▉         | 23/256 [00:05<00:23,  9.80it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):   9%|▉         | 24/256 [00:05<00:23,  9.83it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):   9%|▉         | 24/256 [00:05<00:23,  9.83it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):  10%|▉         | 25/256 [00:05<00:23,  9.83it/s, error=0.003686, best=0.003686]
# Solving nonrigid drift (adam):  10%|▉         | 25/256 [00:05<00:23,  9.83it/s, error=0.003685, best=0.003686]
# Solving nonrigid drift (adam):  10%|█         | 26/256 [00:05<00:23,  9.83it/s, error=0.003685, best=0.003686]
# Solving nonrigid drift (adam):  10%|█         | 26/256 [00:05<00:23,  9.83it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█         | 27/256 [00:05<00:23,  9.83it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█         | 27/256 [00:05<00:23,  9.83it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█         | 28/256 [00:05<00:23,  9.82it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█         | 28/256 [00:06<00:23,  9.82it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█▏        | 29/256 [00:06<00:23,  9.84it/s, error=0.003685, best=0.003685]
# Solving nonrigid drift (adam):  11%|█▏        | 29/256 [00:06<00:23,  9.84it/s, error=0.003684, best=0.003685]
# Solving nonrigid drift (adam):  12%|█▏        | 30/256 [00:06<00:22,  9.84it/s, error=0.003684, best=0.003685]
# Solving nonrigid drift (adam):  12%|█▏        | 30/256 [00:06<00:22,  9.84it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  12%|█▏        | 31/256 [00:06<00:22,  9.87it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  12%|█▏        | 31/256 [00:06<00:22,  9.87it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  12%|█▎        | 32/256 [00:06<00:22,  9.86it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  12%|█▎        | 32/256 [00:06<00:22,  9.86it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  13%|█▎        | 33/256 [00:06<00:22,  9.87it/s, error=0.003684, best=0.003684]
# Solving nonrigid drift (adam):  13%|█▎        | 33/256 [00:06<00:22,  9.87it/s, error=0.003683, best=0.003684]
# Solving nonrigid drift (adam):  13%|█▎        | 34/256 [00:06<00:22,  9.89it/s, error=0.003683, best=0.003684]
# Solving nonrigid drift (adam):  13%|█▎        | 34/256 [00:06<00:22,  9.89it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▎        | 35/256 [00:06<00:22,  9.79it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▎        | 35/256 [00:06<00:22,  9.79it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▍        | 36/256 [00:06<00:22,  9.81it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▍        | 36/256 [00:06<00:22,  9.81it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▍        | 37/256 [00:06<00:22,  9.82it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  14%|█▍        | 37/256 [00:06<00:22,  9.82it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  15%|█▍        | 38/256 [00:06<00:22,  9.83it/s, error=0.003683, best=0.003683]
# Solving nonrigid drift (adam):  15%|█▍        | 38/256 [00:07<00:22,  9.83it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  15%|█▌        | 39/256 [00:07<00:22,  9.83it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  15%|█▌        | 39/256 [00:07<00:22,  9.83it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▌        | 40/256 [00:07<00:21,  9.85it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▌        | 40/256 [00:07<00:21,  9.85it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▌        | 41/256 [00:07<00:21,  9.87it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▌        | 41/256 [00:07<00:21,  9.87it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▋        | 42/256 [00:07<00:21,  9.87it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  16%|█▋        | 42/256 [00:07<00:21,  9.87it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  17%|█▋        | 43/256 [00:07<00:21,  9.85it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  17%|█▋        | 43/256 [00:07<00:21,  9.85it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  17%|█▋        | 44/256 [00:07<00:21,  9.86it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  17%|█▋        | 44/256 [00:07<00:21,  9.86it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 45/256 [00:07<00:21,  9.88it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 45/256 [00:07<00:21,  9.88it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 46/256 [00:07<00:21,  9.88it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 46/256 [00:07<00:21,  9.88it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 47/256 [00:07<00:21,  9.86it/s, error=0.003682, best=0.003682]
# Solving nonrigid drift (adam):  18%|█▊        | 47/256 [00:07<00:21,  9.86it/s, error=0.003681, best=0.003682]
# Solving nonrigid drift (adam):  19%|█▉        | 48/256 [00:07<00:21,  9.86it/s, error=0.003681, best=0.003682]
# Solving nonrigid drift (adam):  19%|█▉        | 48/256 [00:08<00:21,  9.86it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  19%|█▉        | 49/256 [00:08<00:20,  9.88it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  19%|█▉        | 49/256 [00:08<00:20,  9.88it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|█▉        | 50/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|█▉        | 50/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|█▉        | 51/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|█▉        | 51/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|██        | 52/256 [00:08<00:20,  9.88it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  20%|██        | 52/256 [00:08<00:20,  9.88it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██        | 53/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██        | 53/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██        | 54/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██        | 54/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██▏       | 55/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  21%|██▏       | 55/256 [00:08<00:20,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  22%|██▏       | 56/256 [00:08<00:20,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  22%|██▏       | 56/256 [00:08<00:20,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  22%|██▏       | 57/256 [00:08<00:20,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  22%|██▏       | 57/256 [00:08<00:20,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 58/256 [00:08<00:20,  9.86it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 58/256 [00:09<00:20,  9.86it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 59/256 [00:09<00:19,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 59/256 [00:09<00:19,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 60/256 [00:09<00:19,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  23%|██▎       | 60/256 [00:09<00:19,  9.85it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  24%|██▍       | 61/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  24%|██▍       | 61/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  24%|██▍       | 62/256 [00:09<00:19,  9.86it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  24%|██▍       | 62/256 [00:09<00:19,  9.86it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▍       | 63/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▍       | 63/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▌       | 64/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▌       | 64/256 [00:09<00:19,  9.87it/s, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▌       | 64/256 [00:09<00:19,  9.87it/s, converged at cycle 65, error=0.003681, best=0.003681]
# Solving nonrigid drift (adam):  25%|██▌       | 64/256 [00:09<00:29,  6.62it/s, converged at cycle 65, error=0.003681, best=0.003681]

# %% [markdown]
# ## Compare all stages

# %%
drift.plot_combined(
    stage=("initial", "affine", "nonrigid"),
    interactive=INTERACTIVE,
    width=620,
)

# %% [markdown]
# ## Validate every region at near-native detail
#
# Every quadrant should settle within about one pixel of its locally preferred
# translation. Inspect the RGB panels and `current_ncc` together rather than
# treating the global optimization loss as proof of physical registration.
#
# We also tested coarse-to-fine strip correction before this step. It improved
# the affine-only lower field, but the final result was indistinguishable after
# non-rigid correction, so strip is not part of this WS2
# workflow.

# %%
nonrigid_figure, nonrigid_regions = drift.diagnose_affine(
    stage=None,
    smoothing_sigma=0.5,
)

# %%
nonrigid_regions
# Out:
#          region         region_role  row_start  row_stop  column_start  \
# 0      top left  trusted affine fit          0      1024             0
# 1     top right   validation region          0      1024          1024
# 2   bottom left   validation region       1024      2048             0
# 3  bottom right   validation region       1024      2048          1024
#
#    column_stop  grid_row  grid_column  current_ncc  current_yellow  \
# 0         1024         0            0     0.549286        0.565450
# 1         2048         0            1     0.573531        0.543108
# 2         1024         1            0     0.600757        0.550184
# 3         2048         1            1     0.587523        0.551659
#
#    mean_absolute_difference
# 0                  0.038752
# 1                  0.033058
# 2                  0.034409
# 3                  0.034330

# %% [markdown]
# ## Corrected image gallery

# %%
drift.show(
    mode=VIEW_MODE,
    cmap="gray",
    auto_contrast=True,
    link_contrast=True,
    smooth=False,
    show_fft=False,
    save_state=True,
)
# Out:
#   Display bin 3×: 2560×2560 → 853×853 (16 MB preview; full-res detail streams on zoom)

# %% [markdown]
# ## Save the fitted correction
#
# The saved object preserves the regional affine checkpoint and the final
# non-rigid knots. It does not copy the raw EMD files.

# %%
drift.save(RESULT, mode="o")
print(f"Saved: {RESULT}")
# Out:
# Saved: ../data/robustness/wmill_ws2/drift_0070_0071_diagnostics.zip

# %% [markdown]
# ## Reproduce
#
# Run this notebook from `tutorials/advanced` with the `live-env`
# kernel. Regenerate the notebook source with:
#
# ```bash
# python tutorials/template/build_2d_affine_diagnostics_ws2_tutorial.py
# ```
#
# For the publication WS2 pair and its standard non-rigid result, use
# `../2d_nonrigid_ws2.ipynb`.
